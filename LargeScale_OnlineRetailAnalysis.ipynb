# %% [markdown]
# ## Openpyxl
#
# Openpyxl is a Python library used for reading, writing, and modifying Excel files
#
# Data Manipulation – Read data from Excel sheets, modify cell values, and write new data.
#
# Formatting – Change font styles, cell colors, borders, and alignment.
#
# Formulas – Work with Excel formulas within cells.
#
# Charts and Graphs – Create and modify charts.
#
# Pivot Tables – Work with pivot tables.
#
# Handling Multiple Sheets – Create, read, and modify multiple sheets in a workbook

# %%
# !pip install openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 4.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# Loading the online retail data from uci

# %%
# !wget https://archive.ics.uci.edu/static/public/352/online+retail.zip
# Out:
# --2025-02-18 22:08:15--  https://archive.ics.uci.edu/static/public/352/online+retail.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘online+retail.zip’
#
# online+retail.zip       [    <=>             ]  22.62M  30.9MB/s    in 0.7s
#
# 2025-02-18 22:08:16 (30.9 MB/s) - ‘online+retail.zip’ saved [23715478]

# %%
# !unzip online+retail.zip
# Out:
# Archive:  online+retail.zip
#  extracting: Online Retail.xlsx

# %%
df1 = pd.read_excel("Online Retail.xlsx")
df1.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %% [markdown]
# I want to change the object datatype to string.

# %%
df1 = df1.astype({'InvoiceNo': 'string', 'StockCode': 'string', 'Description': 'string', 'Country': 'string'})

# we can use this simple code to convert all object dtype to string using
# df1.astype(str)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  string
#  1   StockCode    541909 non-null  string
#  2   Description  540455 non-null  string
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  string
# dtypes: datetime64[ns](1), float64(2), int64(1), string(4)
# memory usage: 33.1 MB

# %%
df1.shape
# Out:
# (541909, 8)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Dealing with missing values

# %%
df1.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# We have missing values in "Description", "CustomerID" columns.

# %%
df1[df1['Description'].isnull()]
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 622       536414     22139        <NA>        56 2010-12-01 11:52:00
# 1970      536545     21134        <NA>         1 2010-12-01 14:32:00
# 1971      536546     22145        <NA>         1 2010-12-01 14:33:00
# 1972      536547     37509        <NA>         1 2010-12-01 14:33:00
# 1987      536549    85226A        <NA>         1 2010-12-01 14:34:00
# ...          ...       ...         ...       ...                 ...
# 535322    581199     84581        <NA>        -2 2011-12-07 18:26:00
# 535326    581203     23406        <NA>        15 2011-12-07 18:31:00
# 535332    581209     21620        <NA>         6 2011-12-07 18:35:00
# 536981    581234     72817        <NA>        27 2011-12-08 10:33:00
# 538554    581408     85175        <NA>        20 2011-12-08 14:06:00
#
#         UnitPrice  CustomerID         Country
# 622           0.0         NaN  United Kingdom
# ...

# %% [markdown]
# So we can observe that the mostly if the description is Not Available correspondingly CustomerID is NAN.

# %% [markdown]
# So lets deal them individually.

# %%
#Top 5 NA values in Description column
df1[df1['Description'].isnull()].head()
# Out:
#      InvoiceNo StockCode Description  Quantity         InvoiceDate  UnitPrice  \
# 622     536414     22139        <NA>        56 2010-12-01 11:52:00        0.0
# 1970    536545     21134        <NA>         1 2010-12-01 14:32:00        0.0
# 1971    536546     22145        <NA>         1 2010-12-01 14:33:00        0.0
# 1972    536547     37509        <NA>         1 2010-12-01 14:33:00        0.0
# 1987    536549    85226A        <NA>         1 2010-12-01 14:34:00        0.0
#
#       CustomerID         Country
# 622          NaN  United Kingdom
# 1970         NaN  United Kingdom
# 1971         NaN  United Kingdom
# 1972         NaN  United Kingdom
# 1987         NaN  United Kingdom

# %% [markdown]
# Now lets check the rows of each stockcode

# %%
df1[df1.StockCode=="22139"].shape
# Out:
# (993, 8)

# %% [markdown]
# So we have 993 rows with stockcode 22139 and lets see the nullvalues of that stockcode

# %%
df1[df1["StockCode"] == "22139"]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 106       536381     22139  RETROSPOT TEA SET CERAMIC 11 PC         23
# 622       536414     22139                              <NA>        56
# 6392      536942     22139                            amazon        15
# 6885      536982     22139  RETROSPOT TEA SET CERAMIC 11 PC         10
# 7203      537011     22139                              <NA>        -5
# ...          ...       ...                               ...       ...
# 538411    581405     22139  RETROSPOT TEA SET CERAMIC 11 PC          1
# 539531    581439     22139  RETROSPOT TEA SET CERAMIC 11 PC          1
# 540441    581486     22139  RETROSPOT TEA SET CERAMIC 11 PC          6
# 541387    581498     22139  RETROSPOT TEA SET CERAMIC 11 PC          2
# 541726    581570     22139  RETROSPOT TEA SET CERAMIC 11 PC          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# We can observe that fro "22139" stock code the most repeated "Description" is "RETROSPOT TEA SET CERAMIC 11 PC"

# %%
df1[df1.StockCode=="22139"].Description.mode()
# Out:
# 0    RETROSPOT TEA SET CERAMIC 11 PC
# Name: Description, dtype: string

# %% [markdown]
# Now lets create another dataframe with stockcode and description columns

# %%
most_freq = df1[["StockCode","Description"]].value_counts().reset_index()
most_freq
# Out:
#      StockCode                         Description  count
# 0       85123A  WHITE HANGING HEART T-LIGHT HOLDER   2302
# 1        22423            REGENCY CAKESTAND 3 TIER   2200
# 2       85099B             JUMBO BAG RED RETROSPOT   2159
# 3        47566                       PARTY BUNTING   1727
# 4        20725             LUNCH BAG RED RETROSPOT   1638
# ...        ...                                 ...    ...
# 4787    35833P                               check      1
# 4788     21410     COUNTRY COTTAGE  DOORSTOP GREEN      1
# 4789     21412            VINTAGE GOLD TINSEL REEL      1
# 4790     21414             SCALLOP SHELL SOAP DISH      1
# 4791     35972                               check      1
#
# [4792 rows x 3 columns]

# %%
most_freq[most_freq.StockCode=="22139"]
# Out:
#      StockCode                       Description  count
# 37       22139  RETROSPOT TEA SET CERAMIC 11 PC     988
# 4256     22139                            amazon      1

# %% [markdown]
# Lets take the decription with highest count. To do that we can use groupby() function.

# %%
most_freq = most_freq.groupby("StockCode").head(1)

# %%
most_freq.head(10)
# Out:
#   StockCode                         Description  count
# 0    85123A  WHITE HANGING HEART T-LIGHT HOLDER   2302
# 1     22423            REGENCY CAKESTAND 3 TIER   2200
# 2    85099B             JUMBO BAG RED RETROSPOT   2159
# 3     47566                       PARTY BUNTING   1727
# 4     20725             LUNCH BAG RED RETROSPOT   1638
# 5     84879       ASSORTED COLOUR BIRD ORNAMENT   1501
# 6     22720   SET OF 3 CAKE TINS PANTRY DESIGN    1473
# 7     21212     PACK OF 72 RETROSPOT CAKE CASES   1385
# 8     20727             LUNCH BAG  BLACK SKULL.   1350
# 9     22457     NATURAL SLATE HEART CHALKBOARD    1280

# %% [markdown]
# So we can observe that each stock code is having unique description.

# %%
most_freq[most_freq.StockCode=="22139"]
# Out:
#    StockCode                       Description  count
# 37     22139  RETROSPOT TEA SET CERAMIC 11 PC     988

# %%
most_freq.columns = ["StockCode", "freq_Description", "count"]
most_freq.head(3)
# changing the column names of the dataframe
# Out:
#   StockCode                    freq_Description  count
# 0    85123A  WHITE HANGING HEART T-LIGHT HOLDER   2302
# 1     22423            REGENCY CAKESTAND 3 TIER   2200
# 2    85099B             JUMBO BAG RED RETROSPOT   2159

# %% [markdown]
# Lets perform left join fro df1 and most_freq tables

# %%
df2 = df1.merge(most_freq, on="StockCode", how="left")
df2.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
#
#                       freq_Description   count
# 0   WHITE HANGING HEART T-LIGHT HOLDER  2302.0
# 1                  WHITE METAL LANTERN   328.0
# ...

# %% [markdown]
# Non lets replace NAN values of Decription column with freq_description value

# %%
df2['Description'] = df2['Description'].mask(df2['Description'].isnull(), df2['freq_Description'])
df2.isnull().sum()
# Out:
# InvoiceNo                0
# StockCode                0
# Description            112
# Quantity                 0
# InvoiceDate              0
# UnitPrice                0
# CustomerID          135080
# Country                  0
# freq_Description       112
# count                  112
# dtype: int64

# %% [markdown]
# Still we have null values in Description column which means there are StockCode values without description. So lets drop those stockcodes which have no use.

# %%
df2.dropna(subset=['Description'], inplace=True)
df2.isnull().sum()
# Out:
# InvoiceNo                0
# StockCode                0
# Description              0
# Quantity                 0
# InvoiceDate              0
# UnitPrice                0
# CustomerID          134968
# Country                  0
# freq_Description         0
# count                    0
# dtype: int64

# %% [markdown]
# We can Ignore the null values in CustomerID because for the sales transaction it has no impact to predict the sales.
#
# it is ok to have null values in CustomerID column

# %%
df2.drop(columns = ["freq_Description", "count"], inplace=True)

# %%
df2.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# ### Handling Invalid values

# %%
df2.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  541797.000000                         541797  541797.000000
# mean        9.555919  2011-07-04 14:06:48.671255296       4.612067
# min    -80995.000000            2010-12-01 08:26:00  -11062.060000
# 25%         1.000000            2011-03-28 11:36:00       1.250000
# 50%         3.000000            2011-07-20 08:59:00       2.080000
# 75%        10.000000            2011-10-19 11:41:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       218.103428                            NaN      96.769831
#
#           CustomerID
# count  406829.000000
# mean    15287.690570
# min     12346.000000
# 25%     13953.000000
# 50%     15152.000000
# 75%     16791.000000
# max     18287.000000
# std      1713.600303

# %% [markdown]
# We can observe that we have negative values in the columns Quantity and UnitPrice. we couldnot have negative values in these.

# %%
df2[df2.Quantity<0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df2[df2.UnitPrice<0].shape
# Out:
# (2, 8)

# %% [markdown]
# I am assuming that these values are entered by mistake.
#
# we can drop these columns with negative values.
#
# And I got another idea where we can convert the value to positive value so that there will not be any data loss.
#
# df2['Quantity'] = df2['Quantity'].abs()
#
# So we can use abs function to do that but as of now lets create a separate table with positive values

# %%
df3 = df2[(df2['Quantity'] > 0) & (df2['UnitPrice'] > 0)]
df3.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  530104.000000                         530104  530104.000000
# mean       10.542037  2011-07-04 20:16:05.225087744       3.907625
# min         1.000000            2010-12-01 08:26:00       0.001000
# 25%         1.000000            2011-03-28 12:22:00       1.250000
# 50%         3.000000            2011-07-20 12:58:00       2.080000
# 75%        10.000000            2011-10-19 12:39:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   13541.330000
# std       155.524124                            NaN      35.915681
#
#           CustomerID
# count  397884.000000
# mean    15294.423453
# min     12346.000000
# 25%     13969.000000
# 50%     15159.000000
# 75%     16795.000000
# max     18287.000000
# std      1713.141560

# %% [markdown]
# ### Feature Engineering

# %%
df3.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# #### Creating a New column

# %% [markdown]
# Total sales amount for each transaction
#
# By creating this feature we can estimate the sales of each item.

# %%
df4 = df3.copy()

df4['TotalSales'] = df4['Quantity'] * df4['UnitPrice']
df4.head(2)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalSales
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34

# %% [markdown]
# Lets create one more feature which is year

# %%
df4['Year'] = df4['InvoiceDate'].dt.year
df4.sample(6)
# Out:
#        InvoiceNo StockCode                    Description  Quantity  \
# 201768    554323     84879  ASSORTED COLOUR BIRD ORNAMENT        16
# 389858    570488     22966  GINGERBREAD MAN COOKIE CUTTER         1
# 522555    580402     23314   VINTAGE CHRISTMAS TABLECLOTH         2
# 288189    562141     22606     WOODEN SKITTLES GARDEN SET         6
# 207299    554982    47590A    BLUE HAPPY BIRTHDAY BUNTING       120
# 39413     539642     22149     FELTCRAFT 6 FLOWER FRIENDS         2
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalSales  \
# 201768 2011-05-23 15:33:00       1.69     16729.0  United Kingdom       27.04
# 389858 2011-10-10 17:12:00       2.46     14096.0  United Kingdom        2.46
# 522555 2011-12-04 11:55:00      12.50     13536.0  United Kingdom       25.00
# 288189 2011-08-03 10:12:00      12.75     17389.0  United Kingdom       76.50
# 207299 2011-05-29 12:16:00       4.65     17152.0  United Kingdom      558.00
# ...

# %% [markdown]
# ### Data Visualization

# %%
yearly_sales = df4.groupby('Year')['TotalSales'].sum()
yearly_sales
# Out:
# Year
# 2010     823746.140
# 2011    9842938.404
# Name: TotalSales, dtype: float64

# %%
yearly_sales.plot(kind='line', title='Monthly Total Sales Trend', marker='o')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.grid(True)
plt.show()

# %% [markdown]
# We can observe that the sales got increased gradually

# %%
df4['Month'] = df4['InvoiceDate'].dt.month
df4.sample(2)
# Out:
#        InvoiceNo StockCode                    Description  Quantity  \
# 515024    579777     23200                JUMBO BAG PEARS         2
# 369021    569008     23250  VINTAGE RED TRIM ENAMEL BOWL         12
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalSales  \
# 515024 2011-11-30 15:13:00       4.13         NaN  United Kingdom        8.26
# 369021 2011-09-29 18:53:00       1.25     15114.0  United Kingdom       15.00
#
#         Year  Month
# 515024  2011     11
# 369021  2011      9

# %%
monthly_sales = df4.groupby('Month')['TotalSales'].sum()
monthly_sales.plot(kind='line', title='Monthly Total Sales Trend', marker='o')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.grid(True)
plt.show()

# %% [markdown]
# we can observe that Total sales started rising up in August having a peek in November. This is likely due to the holiday season at the end of the year
